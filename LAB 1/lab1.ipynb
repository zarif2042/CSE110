# %%
#Task 1
print("hello world");
# Out:
# hello world

# %%
#Task 2
print(54+56);
# Out:
# 110

# %%
#Task 3
season = "Summer"
year = 2023
print(season + str(year));
# Out:
# Summer2023

# %%
#Task 4
name = input("Enter your name:")
print("Your name is "+name);
# Out:
# Enter your name:Albert
# Your name is Albert

# %%
#Task 5
M = int(input("Enter the value of M:"))
N = int(input("Enter the value of N:"))
result = str(M**N)
print(str(M)+"^"+ str(N) +":"+ result);
# Out:
# Enter the value of M:2
# Enter the value of N:3
# 2^3:8

# %%
#Task 6
total_weight = int(input("Enter the total weight on Tessares Boat:"))
maximum_load = (total_weight//4)*4
print("The maximum load the boat can carry is",maximum_load);
# Out:
# Enter the total weight on Tessares Boat:23
# The maximum load the boat can carry is 20

# %%
#Task 7
A = int(input("Enter the value of A:"))
B = int(input("Enter the value of B:"))
C = int(input("Enter the value of C:"))
D = float(input("Enter the value of D:"))

result = (A**C)+B*A-(D/3)
print(int(result))
# Out:
# Enter the value of A:9
# Enter the value of B:100
# Enter the value of C:1
# Enter the value of D:3.7
# 907

# %%
#Task 8
chocolate = int(input("Enter the number of chocolate:"))
friend_choco = chocolate // 3
my_choco = chocolate % 3
print("The number of chocolates each friends have "+str(friend_choco))
print("The number of chocolates I have "+str(my_choco))
# Out:
# Enter the number of chocolate:90
# The number of chocolates each friends have 30
# The number of chocolates I have 0

# %%
#Task 9
M = input("Enter whatever you want:")
N = input("Enter whatever you want:")
print("The bottom up approach "+N+M)
# Out:
# Enter whatever you want:5
# Enter whatever you want:2
# The bottom up approach 25

# %%
#Task 10
num1 = int(input("Enter the first integer number:"))
num2 = float(input("Enter the first floating number"))
num3 = int(input("Enter the second integer number"))
result = num1 + num2
print(str(result)+str(num3));
# Out:
# Enter the first integer number:3
# Enter the first floating number11.57
# Enter the second integer number7
# 14.577

# %%
#Task 11
number = int(input("Enter the number:"))
if (number%2==0):
  print("The number is even.");
else:
  print("The number is odd.");
# Out:
# Enter the number:365
# The number is odd.
